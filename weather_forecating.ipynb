# %%
import pandas as pd
import numpy as np

# %%
dfData_one_feature = pd.read_excel("Data_one_feature.xlsx")
dfData = pd.read_excel("Data_several_features.xlsx")
dfTarget = pd.read_excel("TargetData_small_sample.xlsx")

# %%
print (dfData_one_feature.shape)
print (dfData.shape)
print (dfTarget.shape)

data_one_feature = np.array(dfData_one_feature.as_matrix())
data = np.array(dfData.as_matrix())
target = np.squeeze(np.asarray(dfTarget.as_matrix()))

# print (data)
# print (target)
# Out:
# (366, 1)
# (366, 2)
# (366, 1)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.hist(target)
plt.xlabel('temperature')
plt.ylabel('count')

# %%
from sklearn.model_selection import train_test_split



X_train_one_feature, X_test_one_feature, y_train_one_feature, y_test_one_feature = train_test_split(data_one_feature, target)

X_train, X_test, y_train, y_test = train_test_split(data, target)

# %%
from sklearn.linear_model import LinearRegression



clf_one_feature = LinearRegression()
clf = LinearRegression()

clf_one_feature.fit(X_train_one_feature, y_train_one_feature)
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predicted_one_feature = clf_one_feature.predict(X_test_one_feature)
predicted = clf.predict(X_test)
expected = y_test

# %%
plt.scatter(predicted, expected)
plt.plot([18, 28], [10, 40])

print (np.corrcoef(predicted, expected))

print (len(predicted))

print (len(expected))
# Out:
# [[ 1.          0.58664737]
#  [ 0.58664737  1.        ]]
# 92
# 92

# %%
plt.scatter(predicted_one_feature, y_test_one_feature)
plt.plot([18, 28], [10, 40])

print (np.corrcoef(predicted_one_feature, y_test_one_feature))
# Out:
# [[ 1.          0.53594931]
#  [ 0.53594931  1.        ]]
